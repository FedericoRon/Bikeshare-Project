# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

df1 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks H-Farm/raw_meteo_data/meteo_data.csv')
df2 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks H-Farm/bike_data/bike_data.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (6,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df1.drop('Unnamed: 0', axis = 1, inplace= True)
df2.drop('Unnamed: 0', axis = 1, inplace= True)

# %%
df1
# Out:
#                                Name  ...        Conditions
# 0     Washington, DC, United States  ...          Overcast
# 1     Washington, DC, United States  ...    Snow, Overcast
# 2     Washington, DC, United States  ...    Snow, Overcast
# 3     Washington, DC, United States  ...    Snow, Overcast
# 4     Washington, DC, United States  ...    Snow, Overcast
# ...                             ...  ...               ...
# 2130  Washington, DC, United States  ...    Rain, Overcast
# 2131  Washington, DC, United States  ...  Partially cloudy
# 2132  Washington, DC, United States  ...             Clear
# 2133  Washington, DC, United States  ...             Clear
# 2134  Washington, DC, United States  ...             Clear
#
# [2135 rows x 17 columns]

# %%
df2
# Out:
#                  ride_id rideable_type  ...    end_lng member_casual
# 0       0F961E4450F8544E  classic_bike  ... -77.033354        casual
# 1       DFD528B4F2B3CA6A  classic_bike  ... -77.030230        member
# 2       2398431BB0EB78BE  classic_bike  ... -77.030230        member
# 3       6E32C58697957443  classic_bike  ... -77.030230        member
# 4       2DCACE8B26B0A50A  classic_bike  ... -77.030230        member
# ...                  ...           ...  ...        ...           ...
# 465428  C84D318AFEE77E7C  classic_bike  ... -77.053485        casual
# 465429  6CA6F4009BC6D668  classic_bike  ... -77.053485        casual
# 465430  941642B7BA047303  classic_bike  ... -77.059142        casual
# 465431  BF443A5C264FD978  classic_bike  ... -77.053485        member
# 465432  9A64DA954BB2B33B  classic_bike  ... -77.053485        member
#
# [465433 rows x 13 columns]

# %%
df2['Date time'] = pd.to_datetime(df2['started_at']).dt.floor('h')
df2
# Out:
#                  ride_id rideable_type  ... member_casual           Date time
# 0       0F961E4450F8544E  classic_bike  ...        casual 2021-02-20 14:00:00
# 1       DFD528B4F2B3CA6A  classic_bike  ...        member 2021-02-15 09:00:00
# 2       2398431BB0EB78BE  classic_bike  ...        member 2021-02-15 09:00:00
# 3       6E32C58697957443  classic_bike  ...        member 2021-02-24 14:00:00
# 4       2DCACE8B26B0A50A  classic_bike  ...        member 2021-02-05 16:00:00
# ...                  ...           ...  ...           ...                 ...
# 465428  C84D318AFEE77E7C  classic_bike  ...        casual 2021-04-17 13:00:00
# 465429  6CA6F4009BC6D668  classic_bike  ...        casual 2021-04-03 15:00:00
# 465430  941642B7BA047303  classic_bike  ...        casual 2021-04-27 17:00:00
# 465431  BF443A5C264FD978  classic_bike  ...        member 2021-04-30 12:00:00
# 465432  9A64DA954BB2B33B  classic_bike  ...        member 2021-04-16 16:00:00
#
# [465433 rows x 14 columns]

# %%
df2['Date time'] = df2['Date time'].dt.strftime('%m/%d/%Y %H:%M:%S')
df2
# Out:
#                  ride_id rideable_type  ... member_casual            Date time
# 0       0F961E4450F8544E  classic_bike  ...        casual  02/20/2021 14:00:00
# 1       DFD528B4F2B3CA6A  classic_bike  ...        member  02/15/2021 09:00:00
# 2       2398431BB0EB78BE  classic_bike  ...        member  02/15/2021 09:00:00
# 3       6E32C58697957443  classic_bike  ...        member  02/24/2021 14:00:00
# 4       2DCACE8B26B0A50A  classic_bike  ...        member  02/05/2021 16:00:00
# ...                  ...           ...  ...           ...                  ...
# 465428  C84D318AFEE77E7C  classic_bike  ...        casual  04/17/2021 13:00:00
# 465429  6CA6F4009BC6D668  classic_bike  ...        casual  04/03/2021 15:00:00
# 465430  941642B7BA047303  classic_bike  ...        casual  04/27/2021 17:00:00
# 465431  BF443A5C264FD978  classic_bike  ...        member  04/30/2021 12:00:00
# 465432  9A64DA954BB2B33B  classic_bike  ...        member  04/16/2021 16:00:00
#
# ...

# %%
type(df2['Date time'][0])
# Out:
# str

# %%
type(df1['Date time'][0])
# Out:
# str

# %%
#df = pd.concat([df1, df2], axis = 1, keys=[df1['Date time']])
df = pd.merge(df2, df1, on ='Date time')
df
# Out:
#                  ride_id  rideable_type  ... Relative Humidity        Conditions
# 0       0F961E4450F8544E   classic_bike  ...             37.74  Partially cloudy
# 1       35963C4C0D258D36   classic_bike  ...             37.74  Partially cloudy
# 2       A10A49E99B400555  electric_bike  ...             37.74  Partially cloudy
# 3       B7FB0390812253D8  electric_bike  ...             37.74  Partially cloudy
# 4       7FF5AC0E07650D14   classic_bike  ...             37.74  Partially cloudy
# ...                  ...            ...  ...               ...               ...
# 465428  4CB8E71253A9C4C3  electric_bike  ...             55.20             Clear
# 465429  45FE5D252325A2EC  electric_bike  ...             55.20             Clear
# 465430  0CA6146B09966CFD  electric_bike  ...             55.20             Clear
# 465431  D33CBB3713F33D02  electric_bike  ...             89.33    Rain, Overcast
# 465432  16A6A18BC2C077BA  electric_bike  ...             89.33    Rain, Overcast
#
# ...

# %%
df.drop(columns= ['Name'], inplace= True)

# %%
df.columns
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual', 'Date time', 'Maximum Temperature',
#        'Minimum Temperature', 'Temperature', 'Wind Chill', 'Heat Index',
#        'Precipitation', 'Snow', 'Snow Depth', 'Wind Speed', 'Wind Direction',
#        'Wind Gust', 'Visibility', 'Cloud Cover', 'Relative Humidity',
#        'Conditions'],
#       dtype='object')

# %%
df =  df[['rideable_type', 'Date time', 'started_at', 'ended_at',
       'start_station_name', 'start_station_id', 'end_station_name',
       'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
       'member_casual', 'Maximum Temperature',
       'Minimum Temperature', 'Temperature', 'Wind Chill', 'Heat Index',
       'Precipitation', 'Snow', 'Snow Depth', 'Wind Speed', 'Wind Direction',
       'Wind Gust', 'Visibility', 'Cloud Cover', 'Relative Humidity',
       'Conditions']]
df
# Out:
#         rideable_type            Date time  ... Relative Humidity        Conditions
# 0        classic_bike  02/20/2021 14:00:00  ...             37.74  Partially cloudy
# 1        classic_bike  02/20/2021 14:00:00  ...             37.74  Partially cloudy
# 2       electric_bike  02/20/2021 14:00:00  ...             37.74  Partially cloudy
# 3       electric_bike  02/20/2021 14:00:00  ...             37.74  Partially cloudy
# 4        classic_bike  02/20/2021 14:00:00  ...             37.74  Partially cloudy
# ...               ...                  ...  ...               ...               ...
# 465428  electric_bike  04/21/2021 02:00:00  ...             55.20             Clear
# 465429  electric_bike  04/21/2021 02:00:00  ...             55.20             Clear
# 465430  electric_bike  04/21/2021 02:00:00  ...             55.20             Clear
# 465431  electric_bike  04/01/2021 03:00:00  ...             89.33    Rain, Overcast
# ...

# %%
df.sort_values(by=['Date time'], inplace= True)
df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#         rideable_type            Date time  ... Relative Humidity Conditions
# 65247   electric_bike  02/01/2021 00:00:00  ...             90.20   Overcast
# 65248    classic_bike  02/01/2021 00:00:00  ...             90.20   Overcast
# 65246    classic_bike  02/01/2021 00:00:00  ...             90.20   Overcast
# 65245    classic_bike  02/01/2021 00:00:00  ...             90.20   Overcast
# 65244   electric_bike  02/01/2021 00:00:00  ...             90.20   Overcast
# ...               ...                  ...  ...               ...        ...
# 394071  electric_bike  04/30/2021 23:00:00  ...             36.95      Clear
# ...

# %%
df['ended_at'] = pd.to_datetime(df['ended_at'])
df['started_at'] = pd.to_datetime(df['started_at'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df['Duration'] = (df['ended_at'] - df['started_at']).dt.total_seconds()
df
# Out:
#         rideable_type            Date time  ... Conditions Duration
# 65247   electric_bike  02/01/2021 00:00:00  ...   Overcast   3426.0
# 65248    classic_bike  02/01/2021 00:00:00  ...   Overcast    712.0
# 65246    classic_bike  02/01/2021 00:00:00  ...   Overcast    382.0
# 65245    classic_bike  02/01/2021 00:00:00  ...   Overcast   1433.0
# 65244   electric_bike  02/01/2021 00:00:00  ...   Overcast    744.0
# ...               ...                  ...  ...        ...      ...
# 394071  electric_bike  04/30/2021 23:00:00  ...      Clear    875.0
# 394070   classic_bike  04/30/2021 23:00:00  ...      Clear   1124.0
# 394069  electric_bike  04/30/2021 23:00:00  ...      Clear     24.0
# 394076  electric_bike  04/30/2021 23:00:00  ...      Clear    602.0
# 394097   classic_bike  04/30/2021 23:00:00  ...      Clear  40178.0
#
# [465433 rows x 29 columns]

# %%
#df.to_csv('/content/drive/MyDrive/Colab Notebooks H-Farm/merged_data.csv')

# %%
df['start_station_name'].value_counts()
# Out:
# Lincoln Memorial               5820
# New Hampshire Ave & T St NW    5168
# Jefferson Dr & 14th St SW      4673
# 4th St & Madison Dr NW         4554
# 15th & P St NW                 4320
#                                ...
# Campus Commons                    5
# Reston Pkwy & Spectrum Dr         3
# 6035 Warehouse                    3
# Shady Grove Hospital              2
# MTL-ECO5-03                       2
# Name: start_station_name, Length: 632, dtype: int64

# %%
df[df['Temperature'] > 25]
# Out:
#         rideable_type            Date time  ...        Conditions Duration
# 216006  electric_bike  03/11/2021 15:00:00  ...  Partially cloudy    750.0
# 216005    docked_bike  03/11/2021 15:00:00  ...  Partially cloudy    783.0
# 216004    docked_bike  03/11/2021 15:00:00  ...  Partially cloudy    852.0
# 216000   classic_bike  03/11/2021 15:00:00  ...  Partially cloudy    968.0
# 216002   classic_bike  03/11/2021 15:00:00  ...  Partially cloudy   1104.0
# ...               ...                  ...  ...               ...      ...
# 254561  electric_bike  04/29/2021 23:00:00  ...          Overcast    504.0
# 254562  electric_bike  04/29/2021 23:00:00  ...          Overcast    232.0
# 254563  electric_bike  04/29/2021 23:00:00  ...          Overcast    344.0
# 254564  electric_bike  04/29/2021 23:00:00  ...          Overcast   1737.0
# 254555  electric_bike  04/29/2021 23:00:00  ...          Overcast   1355.0
#
# [23048 rows x 29 columns]
