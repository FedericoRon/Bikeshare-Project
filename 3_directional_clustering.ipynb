# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks H-Farm/data_with_neighbours_final.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (7,9) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df
# Out:
#         Unnamed: 0  Unnamed: 0.1  ... Start count End count
# 0                0         65247  ...       27945     16781
# 1              151         69018  ...       27945     16781
# 2              420         75681  ...       27945     16781
# 3              481         10425  ...       27945     16781
# 4              482         10424  ...       27945     16781
# ...            ...           ...  ...         ...       ...
# 465428      427710        305583  ...       26742      9742
# 465429      432825        439597  ...       26742      9742
# 465430      439139        353360  ...       26742      9742
# 465431      460419        349960  ...       26742      9742
# 465432      461541        284864  ...       26742      9742
#
# [465433 rows x 41 columns]

# %%
df['closest distrect from start copy'] = df['closest distrect from start']
df['closest distrect from end copy'] = df['closest distrect from end']

# %%
#new_macrodistricts = {"closest distrect from start":     {0: 'skirt1', 1: 'outskirtsouth', 2: 'outskirteast', 3: 'downtown', 4:'skirt2'\
  #                                                        5: 'skirt2', 6:'outskirtsouth',7: 'downtown', 8:'downtown', 9: 'skirt1'\
#                                                         14:'skirt1', 15: 'skirt2', 16: 'skirt2', 17: 'skirt1', 18: 'outskirtnorthwest'\
#                                                          19: 'skirt1', 20: 'outskirtsouth', 21: 'skirt1', 22: 'outskirtnorthwest',23:'outskirtnorthwest'\
 #                                                         24: 'outskirtsouthwest'}
#df = df.replace(new_conditions)

# %%
#new_macrodistricts = {"closest distrect from end":      {0: 'skirt1', 1: 'outskirtsouth', 2: 'outskirteast', 3: 'downtown', 4:'skirt2'\
  #                                                        5: 'skirt2', 6:'outskirtsouth',7: 'downtown', 8:'downtown', 9: 'skirt1'\
#                                                         14:'skirt1', 15: 'skirt2', 16: 'skirt2', 17: 'skirt1', 18: 'outskirtnorthwest'\
#                                                          19: 'skirt1', 20: 'outskirtsouth', 21: 'skirt1', 22: 'outskirtnorthwest',23:'outskirtnorthwest'\
 #                                                         24: 'outskirtsouthwest'}
#df = df.replace(new_macrodistricts)

# %%
#df.groupby(['closest distrect from start'])['Start count'].count().plot(kind = 'bar')

# %%
#df.groupby(['closest distrect from end'])['Start count'].count().plot(kind = 'bar')

# %%
new_macrodistricts = {"closest distrect from start copy":     {0: 'skirt1', 1: 'outskirt', 2: 'outskirt', 3: 'downtown', 4:'skirt2',\
                                                        5: 'skirt2', 6:'outskirt',7: 'downtown', 8:'downtown', 9: 'skirt1',\
                                                        10: 'skirt2', 11: 'outskirt', 12:'outskirt',13:'downtown',\
                                                         14:'skirt1', 15: 'skirt2', 16: 'skirt2', 17: 'skirt1', 18: 'outskirt',\
                                                          19: 'skirt1', 20: 'outskirt', 21: 'skirt1', 22: 'outskirt',23:'outskirt',\
                                                         24: 'outskirt'}}
df = df.replace(new_macrodistricts)

# %%
new_macrodistricts = {"closest distrect from end copy":       {0: 'skirt1', 1: 'outskirt', 2: 'outskirt', 3: 'downtown', 4:'skirt2',\
                                                        5: 'skirt2', 6:'outskirt',7: 'downtown', 8:'downtown', 9: 'skirt1',\
                                                        10: 'skirt2', 11: 'outskirt', 12:'outskirt',13:'downtown',\
                                                         14:'skirt1', 15: 'skirt2', 16: 'skirt2', 17: 'skirt1', 18: 'outskirt',\
                                                          19: 'skirt1', 20: 'outskirt', 21: 'skirt1', 22: 'outskirt',23:'outskirt',\
                                                         24: 'outskirt'}}
df = df.replace(new_macrodistricts)

# %%
df
# Out:
#         Unnamed: 0  ...  closest distrect from end copy
# 0                0  ...                        outskirt
# 1              151  ...                        outskirt
# 2              420  ...                        outskirt
# 3              481  ...                        outskirt
# 4              482  ...                        outskirt
# ...            ...  ...                             ...
# 465428      427710  ...                        outskirt
# 465429      432825  ...                        outskirt
# 465430      439139  ...                        outskirt
# 465431      460419  ...                        outskirt
# 465432      461541  ...                        outskirt
#
# [465433 rows x 43 columns]

# %%
df.groupby(['closest distrect from start copy'])['Start count'].count().plot(kind = 'bar')

# %%
df.groupby(['closest distrect from end copy'])['Start count'].count().plot(kind = 'bar')

# %%
df.groupby(['closest distrect from start','closest distrect from end'])[['Start district name']].count().head(50)
# Out:
#                                                        Start district name
# closest distrect from start closest distrect from end
# 0                           0                                         4806
#                             1                                           44
#                             2                                          160
#                             3                                          250
#                             4                                          126
#                             5                                         2750
#                             6                                           21
#                             7                                         2394
#                             8                                         3438
#                             9                                         2610
#                             10                                         923
# ...

# %%
#df.to_csv('/content/drive/MyDrive/Colab Notebooks H-Farm/data_with_neighbours_final_with_cluster.csv')
